# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitij04Poojary/Synapse_LP/blob/Week7/Copy_of_Synapse_CV_Week_2_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image Segmentation ( Make sure you are using the T4 GPU Runtime )

# %% [markdown]
# This task focuses on <a href="https://www.v7labs.com/blog/image-segmentation-guide" class="external">Image Segmentation</a> and Object Detection.
#
# ## What is image segmentation?
#
# In an image classification task, the network assigns a label (or class) to each input image. However, suppose you want to know the shape of that object, which pixel belongs to which object, etc. In this case, you need to assign a class to each pixel of the image—this task is known as segmentation. A segmentation model returns much more detailed information about the image. Image segmentation has many applications in medical imaging, self-driving cars and satellite imaging, just to name a few.
#
# This task uses the [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/) ([Parkhi et al, 2012](https://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf)). The dataset consists of images of 37 pet breeds, with 200 images per breed (~100 each in the training and test splits). Each image includes the corresponding labels, and pixel-wise masks. The masks are class-labels for each pixel. Each pixel is given one of three categories:
#
# - Class 1: Pixel belonging to the pet.
# - Class 2: Pixel bordering the pet.
# - Class 3: None of the above/a surrounding pixel.

# %% [markdown]
# ## Environment Setup

# %%
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# !tar -xf images.tar.gz
# !tar -xf annotations.tar.gz
# Out:
# --2024-01-17 14:03:40--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz [following]
# --2024-01-17 14:03:40--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz [following]
# --2024-01-17 14:03:41--  https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz [following]
# --2024-01-17 14:03:41--  https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  21.1MB/s    in 37s
#
# 2024-01-17 14:04:19 (20.2 MB/s) - ‘images.tar.gz’ saved [791918971/791918971]
#
# URL transformed to HTTPS due to an HSTS policy
# --2024-01-17 14:04:19--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz [following]
# --2024-01-17 14:04:20--  https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz [following]
# --2024-01-17 14:04:20--  https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173078 (18M) [application/octet-stream]
# Saving to: ‘annotations.tar.gz’
#
# annotations.tar.gz  100%[===================>]  18.28M  11.2MB/s    in 1.6s
#
# 2024-01-17 14:04:22 (11.2 MB/s) - ‘annotations.tar.gz’ saved [19173078/19173078]

# %%
# !pip install -q git+https://github.com/tensorflow/examples.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-examples (setup.py) ... done

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from tensorflow.keras.utils import array_to_img
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow_examples.models.pix2pix import pix2pix
import numpy as np
import random
from IPython.display import clear_output
import matplotlib.pyplot as plt
import gc

# %% [markdown]
# ## Data Loading

# %%
input_dir = "images/"
target_dir = "annotations/trimaps/"

# Loading Image Paths
input_img_paths = sorted(
    [os.path.join(input_dir, fname)
     for fname in os.listdir(input_dir)
     if fname.endswith(".jpg")])
target_paths = sorted(
    [os.path.join(target_dir, fname)
     for fname in os.listdir(target_dir)
     if fname.endswith(".png") and not fname.startswith(".")])

# %%
# Checking if the Paths loaded correctly
plt.axis("off")
plt.imshow(load_img(input_img_paths[9]))

# %%
# Function for Displaying Masked Image (Segmented Image)
def display_target(target_array):
    normalized_array = (target_array.astype("uint8") - 1) * 127 # Normalizing the Image
    plt.axis("off")
    plt.imshow(normalized_array[:, :, 0])

img = img_to_array(load_img(target_paths[9], color_mode="grayscale")) # Loading a single image
display_target(img)

# %%
# Loading entire Dataset
img_size = (200,200) # set it as 200x200 ka tuple
num_imgs = len(input_img_paths)

#random.Random(1337) # Shuffle the Paths (input_img_paths and target_paths)
random.seed(1337)  # Set the seed for reproducibility
combined_paths = list(zip(input_img_paths, target_paths))
random.shuffle(combined_paths)
input_img_paths, target_paths = zip(*combined_paths)

# Create function to load input image from path
def path_to_input_image(path):
  inp_img=img_to_array(load_img(path,target_size=img_size))
  return inp_img

# Create function to load target image from path
def path_to_target(path):
    img =img_to_array(load_img(path, color_mode="grayscale",target_size=img_size))
    return img

input_imgs = np.zeros((num_imgs,) + img_size + (3,), dtype="float32")
targets = np.zeros((num_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_imgs):
    input_imgs[i] = path_to_input_image(input_img_paths[i])
    targets[i] = path_to_target(target_paths[i])

num_val_samples = 1000 # Play around with it if want to
train_input_imgs = input_imgs[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_input_imgs = input_imgs[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %% [markdown]
# ## Model
#
# A Image Segmentation Model, at its core, typically comprises a convolutional neural network (CNN) architecture, leveraging its ability to capture hierarchical features in an image. The model consists of encoder or Downsampler and decoder or Upsampler components, where the encoder extracts relevant features from the input image, and the decoder reconstructs the segmented output.
#
# Each Conv2D layer in the encoder applies filters to the input image, extracting low-level to high-level features. As you move deeper into the encoder, the spatial dimensions of the feature maps typically decrease while the depth (number of channels) increases.
#
# Conv2DTranspose layers are employed in the decoder to upsample the feature maps, gradually increasing the spatial dimensions while reducing the number of channels. Skip connections are often added between corresponding encoder and decoder layers to preserve fine-grained details.

# %%
def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))
    x = layers.Rescaling(1.0/255)(inputs)# Create a Rescaling layer to convert the range [0,255] to [0,1]

    # Similarly add 6 Conv2D Layers with Relu Activation, Strides as required in alternate layers (for layers with even index) (Try khudse) and padding so that output size is equal to input size.
    # This Block acts as our Encoder Block to understand features of the Input Image
    x=layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)
    x=layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)
    x=layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)
    x=layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)
    x=layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)
    x=layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)

    # Now add 6 Conv2DTranspose Layers with Relu, strides in alternate layers (for layers with odd indexes) and same padding.
    '''This Block acts as our Decoder Block to regenerate the Image from the Convoluted Feature Map. This allows for linking and expanding
    the Segmented Features to the original Image.'''
    x = layers.Conv2DTranspose(filters=256, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)
    x = layers.Conv2DTranspose(filters=256, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)
    x = layers.Conv2DTranspose(filters=128, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)
    x = layers.Conv2DTranspose(filters=128, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)
    x = layers.Conv2DTranspose(filters=64, kernel_size=(3, 3), activation='relu', strides=(1,1), padding='same')(x)
    x = layers.Conv2DTranspose(filters=64, kernel_size=(3, 3), activation='relu', strides=(2,2), padding='same')(x)

   # Finally, add a softmax with same padding to get the final Segmented Image
    outputs =layers.Conv2D(filters=num_classes,kernel_size=(3,3),activation='softmax',padding='same')(x)

    # Create the Model using the Model API
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

model = get_model(img_size=img_size, num_classes=3) # Why num_classes = 3 here? Batao Sochke
#Because we have 3 classes in each image: Class 1: Pixel belonging to the pet. Class 2: Pixel bordering the pet. Class 3: None of the above/a surrounding pixel.
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTr  (None, 25, 25, 256)       590080
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 50, 50, 256)       590080
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 50, 50, 128)       295040
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, 100, 100, 128)     147584
#  Transpose)
#
#  conv2d_transpose_4 (Conv2D  (None, 100, 100, 64)      73792
#  Transpose)
#
#  conv2d_transpose_5 (Conv2D  (None, 200, 200, 64)      36928
#  Transpose)
#
#  conv2d_6 (Conv2D)           (None, 200, 200, 3)       1731
#
# =================================================================
# Total params: 2880643 (10.99 MB)
# Trainable params: 2880643 (10.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class DiceLoss(tf.keras.losses.Loss):
    def __init__(self, smooth=1e-6, gama=2):
        super(DiceLoss, self).__init__()
        self.name = 'NDL'
        self.smooth = smooth
        self.gama = gama

    def call(self, y_true, y_pred):
        y_true, y_pred = tf.cast(
            y_true, dtype=tf.float32), tf.cast(y_pred, tf.float32)
        nominator = 2 * \
            tf.reduce_sum(tf.multiply(y_pred, y_true)) + self.smooth
        denominator = tf.reduce_sum(
            y_pred ** self.gama) + tf.reduce_sum(y_true ** self.gama) + self.smooth
        result = 1 - tf.divide(nominator, denominator)
        return result

# %%
dice_loss=DiceLoss()
model.compile(optimizer="adam", loss=dice_loss,metrics=['accuracy']) # Use appropriate Loss function (Hint: Images use kar rhe hai toh konsa use hoga?)
# Callbacks: https://keras.io/api/callbacks/
# We are saving this model after each epoch so that bichme agar band hogaya toh bhi we have somewhere to start with
callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.x",
                                    save_best_only=True, verbose=2)
]

# %% [markdown]
# ## Training and Testing

# %%
# Train the Model for 3 epochs with the batch size of 64, make sure to set the callbacks parameter
# 3 epochs se jyda kiya toh Colab Crash hota sadly.. if you wanna do more, try kaggle pe ya locally
history = model.fit(train_input_imgs, train_targets,batch_size=64,epochs=2,validation_data=(val_input_imgs, val_targets),callbacks=callbacks)
# Out:
# Epoch 1/2
# 100/100 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.3509
# Epoch 1: val_loss improved from inf to 0.09529, saving model to oxford_segmentation.x
# 100/100 [==============================] - 102s 771ms/step - loss: 0.0967 - accuracy: 0.3509 - val_loss: 0.0953 - val_accuracy: 0.5831
# Epoch 2/2
# 100/100 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.2898
# Epoch 2: val_loss did not improve from 0.09529
# 100/100 [==============================] - 59s 589ms/step - loss: 0.0967 - accuracy: 0.2898 - val_loss: 0.0953 - val_accuracy: 0.3001

# %%
# Plotting Loss
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"] # history me se Loss nikalo
val_loss = history.history["val_loss"] # history me se validation loss nikalo
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %%
os.listdir('oxford_segmentation.x')
# Out:
# ['assets',
#  'saved_model.pb',
#  'fingerprint.pb',
#  'variables',
#  'keras_metadata.pb']

# %%
custom_objects = {'DiceLoss': DiceLoss}
saved_model='/content/oxford_segmentation.x'
model = tf.keras.models.load_model(saved_model, custom_objects=custom_objects)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a1ce93f2a0e6> in <cell line: 3>()
#       1 custom_objects = {'DiceLoss': DiceLoss}
#       2 saved_model='/content/oxford_segmentation.x'
# ----> 3 model = tf.keras.models.load_model(saved_model, custom_objects=custom_objects)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in from_config(cls, config)
#     173             A `Loss` instance.
#     174         """
# --> 175         return cls(**config)
#     176
#     177     def get_config(self):
#
# TypeError: DiceLoss.__init__() got an unexpected keyword argument 'reduction'

# %%
# Test Model
def predict(i):
  test_image = val_input_imgs[i]
  plt.axis("off")
  plt.imshow(array_to_img(test_image))
  mask = model.predict()[0] # Predict karo. PS: Look carefully at the dimensions.
  display_mask(mask)

def display_mask(pred):
    mask = np.argmax(pred, axis=-1)
    mask *= 127
    plt.axis("off")
    plt.imshow(mask)

# Use or Modify the above Functions to display 20 test images in the SAME PLOT

# %%
# Garbage Collection so that aage wale parts me issue nhi aaye
del(model,train_input_imgs, train_targets, val_input_imgs, val_targets, history, input_imgs, targets)
gc.collect()

# %% [markdown]
# ## Image Segmentation using Transfer Learning and Existing Architectures

# %% [markdown]
# So now, we implemented a Custom Model for Image Segmentation. Abhi there are a few existing architectures which efficiently do this for us. For example: U-Net, Mask R-CNN, Fast FCN etc.
#
# You can read more about them here:
# https://neptune.ai/blog/image-segmentation#:~:text=The%20basic%20architecture%20in%20image,an%20encoder%20and%20a%20decoder.&text=The%20encoder%20extracts%20features%20from,the%20outline%20of%20the%20object.
#
#
#
# We will now implement U-Net Architecture. It is similar to the one we created above.
# https://www.geeksforgeeks.org/u-net-architecture-explained/

# %% [markdown]
# ## Data Loading

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# Downloading and preparing dataset 773.52 MiB (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteUN7B86/oxford_iiit_pet-train.tfrecord*...:…
# Generating test examples...:   0%|          | 0/3669 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteUN7B86/oxford_iiit_pet-test.tfrecord*...: …
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %%
def normalize(input_image, input_mask):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  input_mask -= 1
  return input_image, input_mask

# %%
def load_image(datapoint):
  input_image = tf.image.resize(datapoint['image'],(128,128)) # Use tf.image to resize datapoint["image"] to (128,128)
  input_mask = tf.image.resize(datapoint["segmentation_mask"],(128,128),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR) # Use Nearest Neighbour Method to resize datapoint["segmentation_mask"] to (128,128) for the image mask

  input_image, input_mask =normalize(input_image,input_mask) # Normalize the Images

  return input_image, input_mask

# %% [markdown]
# The dataset already contains the required training and test splits, so continue to use the same splits:

# %%
TRAIN_LENGTH = info.splits['train'].num_examples
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train_images = dataset['train'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test_images = dataset['test'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# The following class performs a simple augmentation by randomly-flipping an image.
#
# [Image augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation)

# %%
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    # both use the same seed, so they'll make the same random changes.
    self.augment_inputs = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)
    self.augment_labels = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)# Do the same for this

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

# %% [markdown]
# Build the input pipeline, applying the augmentation after batching the inputs:

# %%
train_batches = (
    train_images
    .cache()
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE)) # Prefetch is an important step towards training efficiency as it allows the Model to Fetch the Next Batch of Data while Training on a Different Batch
    # AUTOTUNE allows Tensorflow to automatically adjust the prefetch buffer. Use that.

test_batches = test_images.batch(BATCH_SIZE)

# %% [markdown]
# Visualize an image example and its corresponding mask from the dataset:

# %%
def display(display_list):
  plt.figure(figsize=(11,11))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
# Use the train_batches to obtain 2 images and display them using the function above
num_batches_to_display = 2
for batch in train_batches.take(num_batches_to_display):
    input_images, true_masks = batch

    # Displaying input images and true masks
    display([input_images[0], true_masks[0]])

# %% [markdown]
# ## Define the model
#
# The model being used here is a modified [U-Net](https://arxiv.org/abs/1505.04597). A U-Net consists of an encoder (downsampler) and decoder (upsampler). To learn robust features and reduce the number of trainable parameters, use a pretrained model—[MobileNetV2](https://arxiv.org/abs/1801.04381)—as the encoder. For the decoder, you will use the upsample block, which is already implemented in the [pix2pix](https://github.com/tensorflow/examples/blob/master/tensorflow_examples/models/pix2pix/pix2pix.py) example in the TensorFlow Examples repo.

# %% [markdown]
# As mentioned, the encoder is a pretrained MobileNetV2 model. You will use the model from `tf.keras.applications`. The encoder consists of specific outputs from intermediate layers in the model. Note that the encoder will not be trained during the training process.

# %%
from tensorflow.keras.models import Model
base_model = tf.keras.applications.MobileNetV2(input_shape=(128,128,3),
                                               include_top=False,
                                               weights='imagenet')# Load the MobileNetV2 Pre-trained model without its final Dense Layers with input_shape=[128, 128, 3]

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model using the tf.keras.Model
down_stack =Model(inputs=base_model.input, outputs=base_model_outputs)

# Since this acts as our pre-trained encoder block, make sure to set the layers to be non-trainable
down_stack.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# The decoder/upsampler is simply a series of upsample blocks implemented in TensorFlow examples:

# %%
# Use pix2pix upsample layers to get our unsampling block
up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]

# %%
def unet_model(output_channels:int):
  inputs =tf.keras.layers.Input(shape=(128,128,3)) # Create an Input Layer of shape (128,128,3)

  # Downsampling through the model
  skips = down_stack(inputs)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()([x, skip])# Concatenate X and Skip Layers
    x = concat

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      filters=output_channels, kernel_size=3, strides=2,
      padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# Note that the number of filters on the last layer is set to the number of `output_channels`. This will be one output channel per class.

# %% [markdown]
# ## Train the model
#
# Now, all that is left to do is to compile and train the model.
#
# When running inference, the label assigned to the pixel is the channel with the highest value. This is what the `create_mask` function is doing.

# %%
OUTPUT_CLASSES = 3

# Create the UNet model
model = unet_model(output_channels=OUTPUT_CLASSES)

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
# Use Adam with the appropraite Loss. PS: We are using scalar integers as labels.. toh kuch change aayega loss me

# %% [markdown]
# Plot the resulting model architecture:

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Try out the model to check what it predicts before training:

# %%
def create_mask(pred_mask):
  pred_mask = tf.math.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
sample_image = None
sample_mask = None
def show_predictions(dataset=None, num=1):
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  elif sample_image is not None and sample_mask is not None:
    display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %%
show_predictions()

# %% [markdown]
# The callback defined below is used to observe how the model improves while it is training:

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %% [markdown]
# In the interest of saving time, the number of epochs was kept small, but you may set this higher to achieve more accurate results.

# %%
EPOCHS = 20
VAL_SUBSPLITS = 5
VALIDATION_STEPS = info.splits['test'].num_examples//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_batches, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=test_batches,
                          callbacks=[DisplayCallback()])
# Out:
# Sample Prediction after epoch 20
#
# 57/57 [==============================] - 9s 161ms/step - loss: 0.1674 - accuracy: 0.9315 - val_loss: 0.2673 - val_accuracy: 0.9040

# %%
# Plot Loss and Validation Loss as previously done
epochs = range(1, len(model_history.history["loss"]) + 1)
loss = model_history.history["loss"] # history me se Loss nikalo
val_loss = model_history.history["val_loss"] # history me se validation loss nikalo
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %% [markdown]
# ## Make predictions

# %% [markdown]
# Now, make some predictions.

# %%
show_predictions(test_batches, 3)
# Out:
# 2/2 [==============================] - 1s 42ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 42ms/step

# %% [markdown]
# ## OPTIONAL: Image Segmentation usually involves high class imbalance. Figure out how you can reduce this problem.

# %% [markdown]
# Some techniques to reduce the problem of class imbalance in image segmentation are:
#
# 1)Data Augmentation:
# Increase the variety of training data by applying transformations such as rotation, scaling, flipping, and changes in brightness and contrast. This helps create more diverse samples for the minority classes.
#
# 2)Data Resampling:
# Adjust the balance of classes by oversampling the minority class or undersampling the majority class. Techniques such as Random Oversampling, Random Undersampling, and SMOTE (Synthetic Minority Over-sampling Technique) can be used.
#
# 3)Online Hard Example Mining (OHEM):
# Focus on the harder examples during training by selecting samples with higher loss values. This helps the model pay more attention to challenging instances, which might include instances from minority classes.
#
# 4)Use of Generative Adversarial Networks (GANs):
# GANs can be used to generate synthetic samples for minority classes, which can be added to the training dataset to balance the class distribution.

# %% [markdown]
# # Object Detection

# %% [markdown]
# Object detection is a computer vision technique for locating instances of objects in images or videos.
#
# Read more:
#
# https://www.mathworks.com/discovery/object-detection.html
#
# https://www.analyticsvidhya.com/blog/2022/03/a-basic-introduction-to-object-detection/

# %% [markdown]
# In this, we will not use one of those high performing off-the-shelf object detectors but develop a new one ourselves, from scratch, using plain python, OpenCV, and Tensorflow.
#
# An Object Detection is a combination of two tasks:
# *   Regression of the bound-box coordinates
# *   Classification of the object label
#
# This means that our model has two outputs: namely the object label and the object bound box. Therefore, the model must combine the tasks of classification and regression.

# %% [markdown]
# The Dataset we will be using is:
#
# https://www.kaggle.com/datasets/techzizou/labeled-mask-dataset-yolo-darknet
#
# Drive pe daaldena

# %% [markdown]
# ## Imports

# %%
import os, random
from google.colab import drive
import tensorflow as tf
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Data Loading

# %% [markdown]
# This code basically generates three lists: one for training (holding 70% of the data), one for validation (20% of the data) and one for test (the last 10%). The code also shuffle the data in order to avoid any natural bias.
#
# Note that we are removing the images with more than one masks/objects. This is because we are building a simple object detector able to detect only a single object in an image.

# %%
def list_files(full_data_path = "/content/gdrive/My Drive/Synapse/obj/", image_ext = '.jpg', split_percentage = [70, 20]):

    files = []

    discarded = 0
    masked_instance = 0

    for r, d, f in os.walk(full_data_path):
        for file in f:
            if file.endswith(".txt"):

                # first, let's check if there is only one object
                with open(full_data_path + "/" + file, 'r') as fp:
                    lines = fp.readlines()
                    if len(lines) > 1:
                        discarded += 1
                        continue


                strip = file[0:len(file) - len(".txt")]
                # secondly, check if the paired image actually exist
                image_path = full_data_path + "/" + strip + image_ext
                if os.path.isfile(image_path):
                    # checking the class. '0' means masked, '1' for unmasked
                    if lines[0][0] == '0':
                        masked_instance += 1
                    files.append(strip)

    size = len(files)
    print(str(discarded) + " file(s) discarded")
    print(str(size) + " valid case(s)")
    print(str(masked_instance) + " are masked cases")

    random.shuffle(files)

    split_training = int(split_percentage[0] * size / 100)
    split_validation = split_training + int(split_percentage[1] * size / 100)

    return files[0:split_training], files[split_training:split_validation], files[split_validation:]

training_files, validation_files, test_files = list_files()
# Out:
# 218 file(s) discarded
# 1292 valid case(s)
# 832 are masked cases

# %%
print(str(len(training_files)) + " training files")
print(str(len(validation_files)) + " validation files")
print(str(len(test_files)) + " test files")
# Out:
# 904 training files
# 258 validation files
# 130 test files

# %% [markdown]
# Since our model will be using a fixed 244 x 244 input layer, we need to format any input image before feed it to the model (to train or to predict).

# %%
input_size = 244

def format_image(img, box):
  '''
  1. Get the height and width of the input image.
  2. Calculate the maximum dimension of the image (either height or width).
  3. Calculate the scaling ratio needed to fit the image within the desired input_size.
  4. Calculate the new width and height of the image based on the scaling ratio.
  5. Create a tuple new_size containing the new width and height.
  6. Resize the original image to the new dimensions using linear interpolation.
  7. Create a new image (new_image) of size input_size x input_size initialized with zeros.
  8. Place the resized image in the upper-left corner of new_image, filling the remaining space with zeros.
  '''
  x, y, w, h = box[0], box[1], box[2], box[3]
  img_height, img_width = img.shape[0], img.shape[1]
  max_dim = max(img_height, img_width)
  r = input_size / max_dim
  new_width, new_height = int(img_width * r), int(img_height * r)
  new_size = (new_width, new_height)

  resized_img = cv.resize(img, new_size, interpolation=cv.INTER_LINEAR)

  if len(resized_img.shape) == 2:  # Check if the image is grayscale
      new_image = np.zeros((input_size, input_size, 1), dtype=resized_img.dtype)
      new_image[0:new_height, 0:new_width, 0] = resized_img
  else:
      new_image = np.zeros((input_size, input_size, 3), dtype=resized_img.dtype)
      new_image[0:new_height, 0:new_width, :] = resized_img
  # Calculate the new coordinates and dimensions (new_box) based on the scaling ratio (r)
  new_box=[x * r, y * r, w * r, h * r]

  return new_image, new_box

# %%
def data_load(files, full_data_path = "/content/gdrive/My Drive/Synapse/obj/", image_ext = ".jpg"):
    X = []
    Y = []

    for file in files:
        img = cv.imread(os.path.join(full_data_path, file + image_ext), cv.IMREAD_GRAYSCALE)

        k = 1

        with open(full_data_path + "/" + file + ".txt", 'r') as fp:
            line = fp.readlines()[0]
            if line[0] == '0':
                k = 0

            box = np.array(line[1:].split(), dtype=float)

        img, box = format_image(img, box)
        img = img.astype(float) / 255.
        box = np.asarray(box, dtype=float) / input_size
        label = np.append(box, k)

        X.append(img)
        Y.append(label)

    X = np.array(X)

    X = np.expand_dims(X, axis=3)

    X= np.array(X, dtype=np.float32) # Convert X and Y to tensors with dtype as float32

    Y=np.array(Y, dtype=np.float32)

    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
raw_train_ds = data_load(training_files)

# %%
raw_validation_ds = data_load(validation_files)

# %%
raw_test_ds = data_load(test_files)

# %% [markdown]
# Since our model must implement two tasks — classification and regression — we need two different Loss Functions:
#
# * One for the classification task: we may use any Loss Function usually found in only-classification tasks like Categorical Crossentropy.
# * One for the bound box regression: we can use a regression Loss Function such as Mean Squared Error.

# %%
CLASSES = 2

def format_instance(image, label):
    return image, (tf.one_hot(int(label[4]), CLASSES), [label[0], label[1], label[2], label[3]])

# %%
BATCH_SIZE = 32

# see https://www.tensorflow.org/guide/data_performance

def tune_training_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.repeat() # The dataset be repeated indefinitely.
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_ds = tune_training_ds(raw_train_ds)

# %%
def tune_validation_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(validation_files) // 4)
    dataset = dataset.repeat()
    return dataset

# %%
validation_ds = tune_validation_ds(raw_validation_ds)

# %%
def tune_test_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(1)
    dataset = dataset.repeat()
    return dataset

test_ds = tune_test_ds(raw_test_ds)

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Activation,Flatten,Dense
def build_feature_extractor(inputs):
  x=inputs
  for _ in range(3):  # use 3 pairs of Conv2D and AveragePooling2D with relu activation and kernel size = 3. Keep in mind we will be using
        x = Conv2D(filters=64, kernel_size=(3, 3),activation="relu", padding='same')(x)
        x = AveragePooling2D(pool_size=(3, 3), padding='same')(x)

  return x

def build_model_adaptor(inputs):
    # Use one Flatten and One Dense Relu Layer
    x = Flatten()(inputs)
    x = Dense(units=2,activation='relu')(x)
    return x

def build_classifier_head(inputs):
    # use a Softmax Layer named classifier_head
    x = Activation('softmax', name='classifier_head')(inputs)
    return x

def build_regressor_head(inputs):
    # use a Dense layer with 4 units named regressor_head
    x = Dense(units=4, name='regressor_head')(inputs)
    return x

def build_model(inputs):

    feature_extractor = build_feature_extractor(inputs)

    model_adaptor = build_model_adaptor(feature_extractor)

    classification_head = build_classifier_head(model_adaptor)

    regressor_head = build_regressor_head(model_adaptor)

    model = tf.keras.Model(inputs = inputs, outputs = [classification_head, regressor_head])

    return model

# %% [markdown]
# Now that we have everything, Let's start with training!

# %% [markdown]
# ## Training

# %%
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError
model = build_model(tf.keras.layers.Input(shape=(input_size, input_size, 1,)))

model.compile(
    optimizer='adam',
    loss={
        'classifier_head': 'categorical_crossentropy',
        'regressor_head': 'mean_squared_error'
    },
    metrics={'classifier_head': 'accuracy'}
)# Use Adam and set loss and metric for classifier_head and regressor_head as stated earlier

# %%
# Plot the Model
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
EPOCHS = 100
BATCH_SIZE = 32

history = model.fit(train_ds,
                    steps_per_epoch=(len(training_files) // BATCH_SIZE),
                    validation_data=validation_ds, validation_steps=1,
                    epochs=EPOCHS)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 14s 76ms/step - loss: 0.6774 - classifier_head_loss: 0.6635 - regressor_head_loss: 0.0140 - classifier_head_accuracy: 0.6339 - val_loss: 0.6619 - val_classifier_head_loss: 0.6472 - val_regressor_head_loss: 0.0146 - val_classifier_head_accuracy: 0.6719
# Epoch 2/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.6714 - classifier_head_loss: 0.6576 - regressor_head_loss: 0.0139 - classifier_head_accuracy: 0.6295 - val_loss: 0.6545 - val_classifier_head_loss: 0.6434 - val_regressor_head_loss: 0.0111 - val_classifier_head_accuracy: 0.6719
# Epoch 3/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.6580 - classifier_head_loss: 0.6416 - regressor_head_loss: 0.0164 - classifier_head_accuracy: 0.6384 - val_loss: 0.6368 - val_classifier_head_loss: 0.5959 - val_regressor_head_loss: 0.0408 - val_classifier_head_accuracy: 0.6719
# Epoch 4/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.6418 - classifier_head_loss: 0.6178 - regressor_head_loss: 0.0240 - classifier_head_accuracy: 0.6272 - val_loss: 0.6209 - val_classifier_head_loss: 0.5902 - val_regressor_head_loss: 0.0307 - val_classifier_head_accuracy: 0.6719
# Epoch 5/100
# 28/28 [==============================] - 1s 49ms/step - loss: 0.6267 - classifier_head_loss: 0.5952 - regressor_head_loss: 0.0315 - classifier_head_accuracy: 0.6339 - val_loss: 0.6144 - val_classifier_head_loss: 0.6029 - val_regressor_head_loss: 0.0115 - val_classifier_head_accuracy: 0.6719
# Epoch 6/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.6096 - classifier_head_loss: 0.5771 - regressor_head_loss: 0.0325 - classifier_head_accuracy: 0.6384 - val_loss: 0.5756 - val_classifier_head_loss: 0.5403 - val_regressor_head_loss: 0.0354 - val_classifier_head_accuracy: 0.6719
# Epoch 7/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.5967 - classifier_head_loss: 0.5607 - regressor_head_loss: 0.0360 - classifier_head_accuracy: 0.6272 - val_loss: 0.5613 - val_classifier_head_loss: 0.5198 - val_regressor_head_loss: 0.0415 - val_classifier_head_accuracy: 0.6719
# Epoch 8/100
# 28/28 [==============================] - 1s 54ms/step - loss: 0.5813 - classifier_head_loss: 0.5389 - regressor_head_loss: 0.0424 - classifier_head_accuracy: 0.6339 - val_loss: 0.5567 - val_classifier_head_loss: 0.5298 - val_regressor_head_loss: 0.0268 - val_classifier_head_accuracy: 0.6719
# Epoch 9/100
# 28/28 [==============================] - 1s 52ms/step - loss: 0.5738 - classifier_head_loss: 0.5328 - regressor_head_loss: 0.0409 - classifier_head_accuracy: 0.6317 - val_loss: 0.5395 - val_classifier_head_loss: 0.4837 - val_regressor_head_loss: 0.0558 - val_classifier_head_accuracy: 0.6719
# Epoch 10/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.5598 - classifier_head_loss: 0.5193 - regressor_head_loss: 0.0405 - classifier_head_accuracy: 0.6373 - val_loss: 0.5259 - val_classifier_head_loss: 0.4897 - val_regressor_head_loss: 0.0362 - val_classifier_head_accuracy: 0.6719
# Epoch 11/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.5435 - classifier_head_loss: 0.4966 - regressor_head_loss: 0.0469 - classifier_head_accuracy: 0.6283 - val_loss: 0.5190 - val_classifier_head_loss: 0.4735 - val_regressor_head_loss: 0.0454 - val_classifier_head_accuracy: 0.6719
# Epoch 12/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.5458 - classifier_head_loss: 0.5035 - regressor_head_loss: 0.0422 - classifier_head_accuracy: 0.6272 - val_loss: 0.5184 - val_classifier_head_loss: 0.4392 - val_regressor_head_loss: 0.0793 - val_classifier_head_accuracy: 0.6719
# Epoch 13/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.5176 - classifier_head_loss: 0.4718 - regressor_head_loss: 0.0458 - classifier_head_accuracy: 0.6462 - val_loss: 0.4866 - val_classifier_head_loss: 0.4320 - val_regressor_head_loss: 0.0546 - val_classifier_head_accuracy: 0.6719
# Epoch 14/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.5166 - classifier_head_loss: 0.4690 - regressor_head_loss: 0.0475 - classifier_head_accuracy: 0.6272 - val_loss: 0.4919 - val_classifier_head_loss: 0.4590 - val_regressor_head_loss: 0.0329 - val_classifier_head_accuracy: 0.6719
# Epoch 15/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.5012 - classifier_head_loss: 0.4610 - regressor_head_loss: 0.0402 - classifier_head_accuracy: 0.6339 - val_loss: 0.4682 - val_classifier_head_loss: 0.4266 - val_regressor_head_loss: 0.0416 - val_classifier_head_accuracy: 0.6719
# Epoch 16/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.4812 - classifier_head_loss: 0.4349 - regressor_head_loss: 0.0464 - classifier_head_accuracy: 0.6328 - val_loss: 0.4590 - val_classifier_head_loss: 0.4132 - val_regressor_head_loss: 0.0458 - val_classifier_head_accuracy: 0.6719
# Epoch 17/100
# 28/28 [==============================] - 1s 52ms/step - loss: 0.4684 - classifier_head_loss: 0.4272 - regressor_head_loss: 0.0411 - classifier_head_accuracy: 0.6362 - val_loss: 0.4414 - val_classifier_head_loss: 0.3961 - val_regressor_head_loss: 0.0452 - val_classifier_head_accuracy: 0.6719
# Epoch 18/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.4707 - classifier_head_loss: 0.4323 - regressor_head_loss: 0.0385 - classifier_head_accuracy: 0.6138 - val_loss: 0.4554 - val_classifier_head_loss: 0.4236 - val_regressor_head_loss: 0.0317 - val_classifier_head_accuracy: 0.6719
# Epoch 19/100
# 28/28 [==============================] - 2s 56ms/step - loss: 0.4400 - classifier_head_loss: 0.4012 - regressor_head_loss: 0.0387 - classifier_head_accuracy: 0.6440 - val_loss: 0.4203 - val_classifier_head_loss: 0.3868 - val_regressor_head_loss: 0.0335 - val_classifier_head_accuracy: 0.6719
# Epoch 20/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.4187 - classifier_head_loss: 0.3849 - regressor_head_loss: 0.0338 - classifier_head_accuracy: 0.6328 - val_loss: 0.4289 - val_classifier_head_loss: 0.4000 - val_regressor_head_loss: 0.0289 - val_classifier_head_accuracy: 0.6719
# Epoch 21/100
# 28/28 [==============================] - 1s 50ms/step - loss: 0.4176 - classifier_head_loss: 0.3879 - regressor_head_loss: 0.0297 - classifier_head_accuracy: 0.6339 - val_loss: 0.4106 - val_classifier_head_loss: 0.3863 - val_regressor_head_loss: 0.0243 - val_classifier_head_accuracy: 0.6719
# Epoch 22/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.4107 - classifier_head_loss: 0.3827 - regressor_head_loss: 0.0280 - classifier_head_accuracy: 0.6306 - val_loss: 0.4205 - val_classifier_head_loss: 0.3978 - val_regressor_head_loss: 0.0227 - val_classifier_head_accuracy: 0.6719
# Epoch 23/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.3957 - classifier_head_loss: 0.3700 - regressor_head_loss: 0.0257 - classifier_head_accuracy: 0.6350 - val_loss: 0.4686 - val_classifier_head_loss: 0.4440 - val_regressor_head_loss: 0.0246 - val_classifier_head_accuracy: 0.6719
# Epoch 24/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.3932 - classifier_head_loss: 0.3717 - regressor_head_loss: 0.0215 - classifier_head_accuracy: 0.6317 - val_loss: 0.3840 - val_classifier_head_loss: 0.3634 - val_regressor_head_loss: 0.0206 - val_classifier_head_accuracy: 0.6719
# Epoch 25/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.3683 - classifier_head_loss: 0.3504 - regressor_head_loss: 0.0179 - classifier_head_accuracy: 0.6283 - val_loss: 0.4014 - val_classifier_head_loss: 0.3868 - val_regressor_head_loss: 0.0146 - val_classifier_head_accuracy: 0.6719
# Epoch 26/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.3374 - classifier_head_loss: 0.3238 - regressor_head_loss: 0.0137 - classifier_head_accuracy: 0.6440 - val_loss: 0.4136 - val_classifier_head_loss: 0.4016 - val_regressor_head_loss: 0.0119 - val_classifier_head_accuracy: 0.6719
# Epoch 27/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.3508 - classifier_head_loss: 0.3389 - regressor_head_loss: 0.0119 - classifier_head_accuracy: 0.6183 - val_loss: 0.4044 - val_classifier_head_loss: 0.3939 - val_regressor_head_loss: 0.0105 - val_classifier_head_accuracy: 0.6719
# Epoch 28/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.3121 - classifier_head_loss: 0.3030 - regressor_head_loss: 0.0091 - classifier_head_accuracy: 0.6462 - val_loss: 0.4187 - val_classifier_head_loss: 0.4095 - val_regressor_head_loss: 0.0092 - val_classifier_head_accuracy: 0.6719
# Epoch 29/100
# 28/28 [==============================] - 1s 52ms/step - loss: 0.3229 - classifier_head_loss: 0.3155 - regressor_head_loss: 0.0074 - classifier_head_accuracy: 0.6339 - val_loss: 0.3790 - val_classifier_head_loss: 0.3724 - val_regressor_head_loss: 0.0066 - val_classifier_head_accuracy: 0.6719
# Epoch 30/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.3167 - classifier_head_loss: 0.3110 - regressor_head_loss: 0.0057 - classifier_head_accuracy: 0.6261 - val_loss: 0.3752 - val_classifier_head_loss: 0.3700 - val_regressor_head_loss: 0.0052 - val_classifier_head_accuracy: 0.6719
# Epoch 31/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.3158 - classifier_head_loss: 0.3112 - regressor_head_loss: 0.0046 - classifier_head_accuracy: 0.6272 - val_loss: 0.4252 - val_classifier_head_loss: 0.4209 - val_regressor_head_loss: 0.0043 - val_classifier_head_accuracy: 0.6719
# Epoch 32/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.3061 - classifier_head_loss: 0.3026 - regressor_head_loss: 0.0035 - classifier_head_accuracy: 0.6440 - val_loss: 0.3814 - val_classifier_head_loss: 0.3778 - val_regressor_head_loss: 0.0036 - val_classifier_head_accuracy: 0.6719
# Epoch 33/100
# 28/28 [==============================] - 1s 50ms/step - loss: 0.3326 - classifier_head_loss: 0.3295 - regressor_head_loss: 0.0031 - classifier_head_accuracy: 0.6183 - val_loss: 0.4341 - val_classifier_head_loss: 0.4319 - val_regressor_head_loss: 0.0022 - val_classifier_head_accuracy: 0.6719
# Epoch 34/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2773 - classifier_head_loss: 0.2754 - regressor_head_loss: 0.0019 - classifier_head_accuracy: 0.6607 - val_loss: 0.4033 - val_classifier_head_loss: 0.4016 - val_regressor_head_loss: 0.0018 - val_classifier_head_accuracy: 0.6719
# Epoch 35/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.3082 - classifier_head_loss: 0.3066 - regressor_head_loss: 0.0016 - classifier_head_accuracy: 0.6150 - val_loss: 0.4005 - val_classifier_head_loss: 0.3992 - val_regressor_head_loss: 0.0014 - val_classifier_head_accuracy: 0.6719
# Epoch 36/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2923 - classifier_head_loss: 0.2911 - regressor_head_loss: 0.0012 - classifier_head_accuracy: 0.6317 - val_loss: 0.4630 - val_classifier_head_loss: 0.4620 - val_regressor_head_loss: 9.8539e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 37/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.3070 - classifier_head_loss: 0.3061 - regressor_head_loss: 9.4603e-04 - classifier_head_accuracy: 0.6239 - val_loss: 0.4108 - val_classifier_head_loss: 0.4100 - val_regressor_head_loss: 8.2168e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 38/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2882 - classifier_head_loss: 0.2875 - regressor_head_loss: 6.8531e-04 - classifier_head_accuracy: 0.6239 - val_loss: 0.4196 - val_classifier_head_loss: 0.4190 - val_regressor_head_loss: 5.4372e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 39/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.2705 - classifier_head_loss: 0.2700 - regressor_head_loss: 4.8279e-04 - classifier_head_accuracy: 0.6484 - val_loss: 0.4378 - val_classifier_head_loss: 0.4373 - val_regressor_head_loss: 4.7290e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 40/100
# 28/28 [==============================] - 1s 46ms/step - loss: 0.2823 - classifier_head_loss: 0.2819 - regressor_head_loss: 3.8044e-04 - classifier_head_accuracy: 0.6350 - val_loss: 0.4355 - val_classifier_head_loss: 0.4351 - val_regressor_head_loss: 3.6067e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 41/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2848 - classifier_head_loss: 0.2845 - regressor_head_loss: 2.7996e-04 - classifier_head_accuracy: 0.6306 - val_loss: 0.4437 - val_classifier_head_loss: 0.4435 - val_regressor_head_loss: 2.3043e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 42/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2823 - classifier_head_loss: 0.2821 - regressor_head_loss: 2.0156e-04 - classifier_head_accuracy: 0.6339 - val_loss: 0.3873 - val_classifier_head_loss: 0.3871 - val_regressor_head_loss: 1.9437e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 43/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.2837 - classifier_head_loss: 0.2835 - regressor_head_loss: 1.5778e-04 - classifier_head_accuracy: 0.6339 - val_loss: 0.4926 - val_classifier_head_loss: 0.4925 - val_regressor_head_loss: 1.2214e-04 - val_classifier_head_accuracy: 0.6719
# Epoch 44/100
# 28/28 [==============================] - 2s 56ms/step - loss: 0.2754 - classifier_head_loss: 0.2753 - regressor_head_loss: 1.0818e-04 - classifier_head_accuracy: 0.6417 - val_loss: 0.4357 - val_classifier_head_loss: 0.4357 - val_regressor_head_loss: 9.2583e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 45/100
# 28/28 [==============================] - 1s 51ms/step - loss: 0.2656 - classifier_head_loss: 0.2656 - regressor_head_loss: 7.8878e-05 - classifier_head_accuracy: 0.6395 - val_loss: 0.3939 - val_classifier_head_loss: 0.3938 - val_regressor_head_loss: 7.3934e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 46/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2969 - classifier_head_loss: 0.2968 - regressor_head_loss: 6.0789e-05 - classifier_head_accuracy: 0.6083 - val_loss: 0.3545 - val_classifier_head_loss: 0.3544 - val_regressor_head_loss: 5.2552e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 47/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2847 - classifier_head_loss: 0.2846 - regressor_head_loss: 4.2580e-05 - classifier_head_accuracy: 0.6306 - val_loss: 0.4245 - val_classifier_head_loss: 0.4245 - val_regressor_head_loss: 3.7135e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 48/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2652 - classifier_head_loss: 0.2652 - regressor_head_loss: 2.9553e-05 - classifier_head_accuracy: 0.6529 - val_loss: 0.4118 - val_classifier_head_loss: 0.4118 - val_regressor_head_loss: 2.5349e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 49/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2791 - classifier_head_loss: 0.2791 - regressor_head_loss: 2.0701e-05 - classifier_head_accuracy: 0.6172 - val_loss: 0.4837 - val_classifier_head_loss: 0.4836 - val_regressor_head_loss: 1.6182e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 50/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2558 - classifier_head_loss: 0.2557 - regressor_head_loss: 1.4397e-05 - classifier_head_accuracy: 0.6529 - val_loss: 0.4318 - val_classifier_head_loss: 0.4318 - val_regressor_head_loss: 1.1308e-05 - val_classifier_head_accuracy: 0.6719
# Epoch 51/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2760 - classifier_head_loss: 0.2760 - regressor_head_loss: 1.0875e-05 - classifier_head_accuracy: 0.6217 - val_loss: 0.4306 - val_classifier_head_loss: 0.4305 - val_regressor_head_loss: 8.7381e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 52/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2786 - classifier_head_loss: 0.2786 - regressor_head_loss: 7.5335e-06 - classifier_head_accuracy: 0.6205 - val_loss: 0.4860 - val_classifier_head_loss: 0.4859 - val_regressor_head_loss: 5.7191e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 53/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2658 - classifier_head_loss: 0.2658 - regressor_head_loss: 5.0157e-06 - classifier_head_accuracy: 0.6362 - val_loss: 0.5627 - val_classifier_head_loss: 0.5627 - val_regressor_head_loss: 3.8504e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 54/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2685 - classifier_head_loss: 0.2684 - regressor_head_loss: 3.9514e-06 - classifier_head_accuracy: 0.6429 - val_loss: 0.4462 - val_classifier_head_loss: 0.4462 - val_regressor_head_loss: 3.5339e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 55/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.2786 - classifier_head_loss: 0.2786 - regressor_head_loss: 2.9597e-06 - classifier_head_accuracy: 0.6250 - val_loss: 0.4744 - val_classifier_head_loss: 0.4744 - val_regressor_head_loss: 2.3971e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 56/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.2700 - classifier_head_loss: 0.2700 - regressor_head_loss: 3.1258e-06 - classifier_head_accuracy: 0.6362 - val_loss: 0.4809 - val_classifier_head_loss: 0.4809 - val_regressor_head_loss: 2.8335e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 57/100
# 28/28 [==============================] - 1s 49ms/step - loss: 0.2703 - classifier_head_loss: 0.2703 - regressor_head_loss: 2.7827e-06 - classifier_head_accuracy: 0.6217 - val_loss: 0.4695 - val_classifier_head_loss: 0.4695 - val_regressor_head_loss: 1.5187e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 58/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2578 - classifier_head_loss: 0.2578 - regressor_head_loss: 1.2173e-06 - classifier_head_accuracy: 0.6473 - val_loss: 0.5464 - val_classifier_head_loss: 0.5464 - val_regressor_head_loss: 8.5539e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 59/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2824 - classifier_head_loss: 0.2824 - regressor_head_loss: 1.1443e-06 - classifier_head_accuracy: 0.6217 - val_loss: 0.5568 - val_classifier_head_loss: 0.5568 - val_regressor_head_loss: 1.4755e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 60/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2593 - classifier_head_loss: 0.2593 - regressor_head_loss: 1.0335e-06 - classifier_head_accuracy: 0.6462 - val_loss: 0.4570 - val_classifier_head_loss: 0.4570 - val_regressor_head_loss: 6.7218e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 61/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2717 - classifier_head_loss: 0.2717 - regressor_head_loss: 6.3030e-07 - classifier_head_accuracy: 0.6228 - val_loss: 0.4852 - val_classifier_head_loss: 0.4852 - val_regressor_head_loss: 7.5442e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 62/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2640 - classifier_head_loss: 0.2640 - regressor_head_loss: 1.6179e-06 - classifier_head_accuracy: 0.6484 - val_loss: 0.4115 - val_classifier_head_loss: 0.4115 - val_regressor_head_loss: 7.2626e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 63/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2824 - classifier_head_loss: 0.2824 - regressor_head_loss: 1.0697e-06 - classifier_head_accuracy: 0.6127 - val_loss: 0.5344 - val_classifier_head_loss: 0.5344 - val_regressor_head_loss: 5.3283e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 64/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2708 - classifier_head_loss: 0.2708 - regressor_head_loss: 5.9091e-07 - classifier_head_accuracy: 0.6473 - val_loss: 0.3911 - val_classifier_head_loss: 0.3911 - val_regressor_head_loss: 4.3192e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 65/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2748 - classifier_head_loss: 0.2748 - regressor_head_loss: 5.7775e-07 - classifier_head_accuracy: 0.6239 - val_loss: 0.4153 - val_classifier_head_loss: 0.4153 - val_regressor_head_loss: 7.5726e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 66/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2653 - classifier_head_loss: 0.2653 - regressor_head_loss: 7.9419e-07 - classifier_head_accuracy: 0.6362 - val_loss: 0.4070 - val_classifier_head_loss: 0.4070 - val_regressor_head_loss: 5.0836e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 67/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2733 - classifier_head_loss: 0.2733 - regressor_head_loss: 6.3958e-07 - classifier_head_accuracy: 0.6317 - val_loss: 0.3752 - val_classifier_head_loss: 0.3752 - val_regressor_head_loss: 6.1150e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 68/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.2805 - classifier_head_loss: 0.2805 - regressor_head_loss: 5.8719e-07 - classifier_head_accuracy: 0.6384 - val_loss: 0.4653 - val_classifier_head_loss: 0.4653 - val_regressor_head_loss: 4.4795e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 69/100
# 28/28 [==============================] - 1s 51ms/step - loss: 0.2554 - classifier_head_loss: 0.2554 - regressor_head_loss: 6.1533e-07 - classifier_head_accuracy: 0.6440 - val_loss: 0.4463 - val_classifier_head_loss: 0.4462 - val_regressor_head_loss: 6.1241e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 70/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2864 - classifier_head_loss: 0.2864 - regressor_head_loss: 6.1774e-07 - classifier_head_accuracy: 0.6205 - val_loss: 0.4315 - val_classifier_head_loss: 0.4315 - val_regressor_head_loss: 4.3852e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 71/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2773 - classifier_head_loss: 0.2773 - regressor_head_loss: 1.0480e-06 - classifier_head_accuracy: 0.6205 - val_loss: 0.4148 - val_classifier_head_loss: 0.4148 - val_regressor_head_loss: 7.4845e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 72/100
# 28/28 [==============================] - 1s 49ms/step - loss: 0.2607 - classifier_head_loss: 0.2607 - regressor_head_loss: 1.2476e-06 - classifier_head_accuracy: 0.6417 - val_loss: 0.3908 - val_classifier_head_loss: 0.3908 - val_regressor_head_loss: 4.2854e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 73/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2678 - classifier_head_loss: 0.2678 - regressor_head_loss: 5.8787e-07 - classifier_head_accuracy: 0.6306 - val_loss: 0.3919 - val_classifier_head_loss: 0.3919 - val_regressor_head_loss: 4.3111e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 74/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2676 - classifier_head_loss: 0.2676 - regressor_head_loss: 5.9896e-07 - classifier_head_accuracy: 0.6239 - val_loss: 0.4057 - val_classifier_head_loss: 0.4057 - val_regressor_head_loss: 5.1825e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 75/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2634 - classifier_head_loss: 0.2634 - regressor_head_loss: 7.5405e-07 - classifier_head_accuracy: 0.6417 - val_loss: 0.4086 - val_classifier_head_loss: 0.4086 - val_regressor_head_loss: 4.7448e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 76/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2690 - classifier_head_loss: 0.2690 - regressor_head_loss: 1.3266e-06 - classifier_head_accuracy: 0.6395 - val_loss: 0.4122 - val_classifier_head_loss: 0.4122 - val_regressor_head_loss: 1.1812e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 77/100
# 28/28 [==============================] - 1s 52ms/step - loss: 0.2850 - classifier_head_loss: 0.2850 - regressor_head_loss: 9.3147e-07 - classifier_head_accuracy: 0.6138 - val_loss: 0.4229 - val_classifier_head_loss: 0.4229 - val_regressor_head_loss: 7.3032e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 78/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2497 - classifier_head_loss: 0.2497 - regressor_head_loss: 7.5415e-07 - classifier_head_accuracy: 0.6607 - val_loss: 0.4369 - val_classifier_head_loss: 0.4368 - val_regressor_head_loss: 4.9080e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 79/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2783 - classifier_head_loss: 0.2783 - regressor_head_loss: 1.8894e-06 - classifier_head_accuracy: 0.6172 - val_loss: 0.3917 - val_classifier_head_loss: 0.3917 - val_regressor_head_loss: 1.8410e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 80/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2695 - classifier_head_loss: 0.2695 - regressor_head_loss: 3.5179e-06 - classifier_head_accuracy: 0.6350 - val_loss: 0.3628 - val_classifier_head_loss: 0.3628 - val_regressor_head_loss: 9.1718e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 81/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2710 - classifier_head_loss: 0.2710 - regressor_head_loss: 2.9402e-06 - classifier_head_accuracy: 0.6239 - val_loss: 0.4345 - val_classifier_head_loss: 0.4345 - val_regressor_head_loss: 7.1687e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 82/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2477 - classifier_head_loss: 0.2477 - regressor_head_loss: 6.0623e-06 - classifier_head_accuracy: 0.6529 - val_loss: 0.4556 - val_classifier_head_loss: 0.4556 - val_regressor_head_loss: 6.9381e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 83/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2695 - classifier_head_loss: 0.2695 - regressor_head_loss: 1.4656e-06 - classifier_head_accuracy: 0.6283 - val_loss: 0.4488 - val_classifier_head_loss: 0.4488 - val_regressor_head_loss: 5.6168e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 84/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2739 - classifier_head_loss: 0.2739 - regressor_head_loss: 6.2039e-07 - classifier_head_accuracy: 0.6272 - val_loss: 0.3639 - val_classifier_head_loss: 0.3639 - val_regressor_head_loss: 4.9795e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 85/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2667 - classifier_head_loss: 0.2667 - regressor_head_loss: 5.1149e-07 - classifier_head_accuracy: 0.6283 - val_loss: 0.3918 - val_classifier_head_loss: 0.3918 - val_regressor_head_loss: 4.3618e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 86/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2631 - classifier_head_loss: 0.2631 - regressor_head_loss: 5.6008e-07 - classifier_head_accuracy: 0.6373 - val_loss: 0.3698 - val_classifier_head_loss: 0.3698 - val_regressor_head_loss: 4.4961e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 87/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2672 - classifier_head_loss: 0.2672 - regressor_head_loss: 5.9707e-07 - classifier_head_accuracy: 0.6317 - val_loss: 0.4179 - val_classifier_head_loss: 0.4179 - val_regressor_head_loss: 4.5868e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 88/100
# 28/28 [==============================] - 1s 49ms/step - loss: 0.2731 - classifier_head_loss: 0.2731 - regressor_head_loss: 5.5511e-07 - classifier_head_accuracy: 0.6362 - val_loss: 0.4027 - val_classifier_head_loss: 0.4027 - val_regressor_head_loss: 4.5893e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 89/100
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2656 - classifier_head_loss: 0.2656 - regressor_head_loss: 5.5464e-07 - classifier_head_accuracy: 0.6317 - val_loss: 0.4718 - val_classifier_head_loss: 0.4718 - val_regressor_head_loss: 5.0920e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 90/100
# 28/28 [==============================] - 2s 55ms/step - loss: 0.2601 - classifier_head_loss: 0.2601 - regressor_head_loss: 5.5831e-07 - classifier_head_accuracy: 0.6362 - val_loss: 0.5095 - val_classifier_head_loss: 0.5095 - val_regressor_head_loss: 4.8840e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 91/100
# 28/28 [==============================] - 2s 56ms/step - loss: 0.2774 - classifier_head_loss: 0.2774 - regressor_head_loss: 9.4970e-07 - classifier_head_accuracy: 0.6194 - val_loss: 0.3933 - val_classifier_head_loss: 0.3933 - val_regressor_head_loss: 1.5807e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 92/100
# 28/28 [==============================] - 2s 57ms/step - loss: 0.2656 - classifier_head_loss: 0.2656 - regressor_head_loss: 5.5907e-06 - classifier_head_accuracy: 0.6317 - val_loss: 0.4304 - val_classifier_head_loss: 0.4304 - val_regressor_head_loss: 5.0923e-06 - val_classifier_head_accuracy: 0.6719
# Epoch 93/100
# 28/28 [==============================] - 2s 54ms/step - loss: 0.2656 - classifier_head_loss: 0.2656 - regressor_head_loss: 3.8714e-06 - classifier_head_accuracy: 0.6350 - val_loss: 0.5652 - val_classifier_head_loss: 0.5652 - val_regressor_head_loss: 8.1359e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 94/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2700 - classifier_head_loss: 0.2700 - regressor_head_loss: 8.8423e-07 - classifier_head_accuracy: 0.6250 - val_loss: 0.6179 - val_classifier_head_loss: 0.6179 - val_regressor_head_loss: 5.1492e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 95/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2485 - classifier_head_loss: 0.2485 - regressor_head_loss: 6.3326e-07 - classifier_head_accuracy: 0.6551 - val_loss: 0.4887 - val_classifier_head_loss: 0.4887 - val_regressor_head_loss: 5.2708e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 96/100
# 28/28 [==============================] - 1s 47ms/step - loss: 0.2681 - classifier_head_loss: 0.2681 - regressor_head_loss: 6.1212e-07 - classifier_head_accuracy: 0.6250 - val_loss: 0.4405 - val_classifier_head_loss: 0.4405 - val_regressor_head_loss: 6.3291e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 97/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2623 - classifier_head_loss: 0.2623 - regressor_head_loss: 6.7103e-07 - classifier_head_accuracy: 0.6362 - val_loss: 0.4593 - val_classifier_head_loss: 0.4593 - val_regressor_head_loss: 5.0064e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 98/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2640 - classifier_head_loss: 0.2640 - regressor_head_loss: 6.4925e-07 - classifier_head_accuracy: 0.6328 - val_loss: 0.5192 - val_classifier_head_loss: 0.5192 - val_regressor_head_loss: 5.6753e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 99/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2766 - classifier_head_loss: 0.2766 - regressor_head_loss: 5.6412e-07 - classifier_head_accuracy: 0.6272 - val_loss: 0.4665 - val_classifier_head_loss: 0.4665 - val_regressor_head_loss: 4.6798e-07 - val_classifier_head_accuracy: 0.6719
# Epoch 100/100
# 28/28 [==============================] - 1s 48ms/step - loss: 0.2706 - classifier_head_loss: 0.2706 - regressor_head_loss: 5.8077e-07 - classifier_head_accuracy: 0.6250 - val_loss: 0.5408 - val_classifier_head_loss: 0.5408 - val_regressor_head_loss: 4.2675e-07 - val_classifier_head_accuracy: 0.6719

# %% [markdown]
# ## IoU Metric

# %% [markdown]
# IoU scores how well the predicted bound box overlaps the actual bound box. The idea behind IoU is pretty simple: compare the intersection and union areas between the predicted and actual bound boxes by dividing the intersection by the union. IoU provides a higher score always when the predicted bounding box best matches the actual bounding box (also called ground-truth)

# %%
def intersection_over_union(boxA, boxB):
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
	yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)# Calculate Intersection Area
	boxAArea = (boxA[2] + 1) * (boxA[3] + 1)# Calcualate BoxA Area
	boxBArea = (boxB[2] + 1) * (boxB[3] + 1)# Calculate BoxB Area
	iou = interArea / float(boxAArea + boxBArea - interArea)# Find IOU
	return iou

# %% [markdown]
# ## Prediction

# %%
plt.figure(figsize=(12, 10))

test_list = list(test_ds.take(20).as_numpy_iterator())

image, labels = test_list[0]

for i in range(len(test_list)):

    ax = plt.subplot(4, 5, i + 1)
    image, labels = test_list[i]

    predictions = model(image)

    predicted_box = predictions[1][0] * input_size
    predicted_box = tf.cast(predicted_box, tf.int32)

    predicted_label = predictions[0][0]

    image = image[0]

    actual_label = labels[0][0]
    actual_box = labels[1][0] * input_size
    actual_box = tf.cast(actual_box, tf.int32)

    image = image.astype("float") * 255.0
    image = image.astype(np.uint8)
    image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

    color = (255, 0, 0)
    # print box red if predicted and actual label do not match
    if (predicted_label[0] > 0.5 and actual_label[0] > 0) or (predicted_label[0] < 0.5 and actual_label[0] == 0):
        color = (0, 255, 0)

    img_label = "unmasked"
    if predicted_label[0] > 0.5:
        img_label = "masked"

    predicted_box_n = predicted_box.numpy()
    cv.rectangle(image_color, predicted_box_n, color, 2)
    cv.rectangle(image_color, actual_box.numpy(), (0, 0, 255), 2)
    cv.rectangle(image_color, (predicted_box_n[0], predicted_box_n[1] + predicted_box_n[3] - 20), (predicted_box_n[0] + predicted_box_n[2], predicted_box_n[1] + predicted_box_n[3]), color, -1)
    cv.putText(image_color, img_label, (predicted_box_n[0] + 5, predicted_box_n[1] + predicted_box_n[3] - 5), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0))

    IoU = intersection_over_union(predicted_box.numpy(), actual_box.numpy())

    plt.title("IoU:" + format(IoU, '.4f'))
    plt.imshow(image_color)
    plt.axis("off")

# %% [markdown]
# # RESEARCH WORK:
# Find out about Common Problems in Segmentation and Object Detection and the Solution for the same. Also Find how these Models can be used for Image Generation within GANs and VAEs.

# %% [markdown]
# Common problems in segmentation and object detection tasks include:
#
# 1) Class Imbalance:
#
# Problem: Uneven distribution of classes in the dataset can lead to biased models, where the model may perform well on dominant classes but poorly on minority classes.
# Solution: Use techniques like class-weighting, data augmentation, or over-sampling of minority classes to address class imbalance.
#
# 2) Small Object Detection:
#
# Problem: Detecting small objects in an image can be challenging, especially when they are significantly smaller than the receptive field of the network.
# Solution: Utilize feature pyramid networks (FPN) or similar architectures that combine features from different scales to handle objects of various sizes.
#
# 3) Boundary Ambiguity:
#
# Problem: The network may struggle with precisely defining object boundaries, leading to fuzzy or inaccurate segmentation masks.
# Solution: Incorporate spatial details through high-resolution features and consider post-processing techniques like conditional random fields (CRF) to refine boundaries.
#
# Regarding how segmentation models can be used for image generation within GANs (Generative Adversarial Networks) and VAEs (Variational Autoencoders):
#
# a) GANs:
#
# In the context of GANs, segmentation models can be used to generate realistic and detailed images. The generator of the GAN can be conditioned on segmentation masks, allowing for the generation of images with specific objects or regions highlighted.
#
# b) VAEs:
#
# VAEs, being generative models, can benefit from segmentation as a means of guiding the generation process. By conditioning the VAE on segmentation masks, the generated images can adhere to certain structural constraints.
#
# c) Conditional Image Generation:
#
# Segmentation masks can serve as conditional inputs to both GANs and VAEs. This conditional information helps generate images with specific content, shapes, or objects, making the generated outputs more controlled and meaningful.
#
# d) Image-to-Image Translation:
#
# Segmentation models can be used in conjunction with GANs for tasks like image-to-image translation. For instance, converting satellite images to maps or translating medical images to segmentations.
